# %%
import json

# %%
text = '{"data":[{"author":"朱会振","change":"维持","companyCode":"80064560","datetime":"2016-08-17T08:06:15","infoCode":"APPH51aNXPpRASearchReport","insCode":"10000296","insName":"西南证券","insStar":"3","jlrs":["3003920000","3593240000","4225910000","",""],"rate":"买入","secuFullCode":"603288.SH","secuName":"海天味业","sratingName":"买入","sy":"0.9300","syls":["29","24","21","",""],"sys":["1.11","1.33","1.56","",""],"title":"业绩稳健增长，盈利能力创历史新高","profitYear":"2015","type":"1","newPrice":"32.18"},{"author":"陈鹏,李强,余驰","change":"维持","companyCode":"80064560","datetime":"2016-08-17T11:31:30","infoCode":"APPH51aNXRU7ASearchReport","insCode":"10001005","insName":"东北证券","insStar":"3","jlrs":["2875330000","3285390000","3785470000","",""],"rate":"增持","secuFullCode":"603288.SH","secuName":"海天味业","sratingName":"增持","sy":"0.9300","syls":["30","27","23.16","",""],"sys":["1.06","1.21","1.4","",""],"title":"二季度增速回升，业绩符合预期","profitYear":"2015","type":"1","newPrice":"32.18"},{"author":"余春生","change":"维持","companyCode":"80064560","datetime":"2016-08-17T13:20:47","infoCode":"APPH51aNXRtJASearchReport","insCode":"10001055","insName":"国海证券","insStar":"3","jlrs":["2932000000","3464000000","4078000000","",""],"rate":"增持","secuFullCode":"603288.SH","secuName":"海天味业","sratingName":"增持","sy":"0.9300","syls":["29.83","25.25","21.45","",""],"sys":["1.08","1.28","1.51","",""],"title":"二季度增长重回两位数，长期仍具较大增长空间","profitYear":"2015","type":"1","newPrice":"32.18"},{"author":"胡彦超","change":"维持","companyCode":"80064560","datetime":"2016-08-16T09:15:36","infoCode":"APPH51LPGpgNASearchReport","insCode":"80000157","insName":"中泰证券","insStar":"4","jlrs":["2984000000","3612000000","4297000000","",""],"rate":"买入","secuFullCode":"603288.SH","secuName":"海天味业","sratingName":"买入","sy":"0.9300","syls":["","30","","",""],"sys":["1.1","1.33","1.59","",""],"title":"三大品类增速均放缓，盈利能力再创新高","profitYear":"2015","type":"1","newPrice":"32.18"},{"author":"张宇光,文献,王俏怡","change":"维持","companyCode":"80064560","datetime":"2016-08-16T09:37:30","infoCode":"APPH51LPGpiwASearchReport","insCode":"80000037","insName":"平安证券","insStar":"4","jlrs":["2830000000","3290000000","3828000000","",""],"rate":"买入","secuFullCode":"603288.SH","secuName":"海天味业","sratingName":"强烈推荐","sy":"0.9300","syls":["31","27","23","",""],"sys":["1.05","1.22","1.41","",""],"title":"行业压力显现，期待新思路取得突破","profitYear":"2015","type":"1","newPrice":"32.18"},{"author":"刘颜","change":"维持","companyCode":"80064560","datetime":"2016-08-16T14:23:40","infoCode":"APPH51LPGrqUASearchReport","insCode":"10001081","insName":"长江证券","insStar":"4","jlrs":["2905900000","3328800000","3816100000","",""],"rate":"买入","secuFullCode":"603288.SH","secuName":"海天味业","sratingName":"买入","sy":"0.9300","syls":["30.42","26.56","23.17","",""],"sys":["1.07","1.23","1.41","",""],"title":"非酱油品类增速降级拖累增速，期待新品拓展带来新引擎","profitYear":"2015","type":"1","newPrice":"32.18"},{"author":"黄付生","change":"维持","companyCode":"80064560","datetime":"2016-08-16T18:45:21","infoCode":"APPH51LPGtiIASearchReport","insCode":"80066058","insName":"中信建投","insStar":"5","jlrs":["2987200000","3520130000","3954280000","",""],"rate":"增持","secuFullCode":"603288.SH","secuName":"海天味业","sratingName":"增持","sy":"0.9300","syls":["24.63","20.9","18.61","",""],"sys":["1.1","1.3","1.46","",""],"title":"产品升级毛利率提升 小众品类增速高于酱油","profitYear":"2015","type":"1","newPrice":"32.18"},{"author":"张宇光,文献,王俏怡","change":"维持","companyCode":"80064560","datetime":"2016-06-30T08:36:32","infoCode":"APPH4GFiRas4ASearchReport","insCode":"80000037","insName":"平安证券","insStar":"4","jlrs":["2830000000","3290000000","3828000000","",""],"rate":"买入","secuFullCode":"603288.SH","secuName":"海天味业","sratingName":"强烈推荐","sy":"0.9300","syls":["29.5","25.4","21.8","",""],"sys":["1.05","1.22","1.41","",""],"title":"经济下行酱油承压，转变思路持续成长","profitYear":"2015","type":"1","newPrice":"32.18"},{"author":"陈鹏,李强,余驰","change":"维持","companyCode":"80064560","datetime":"2016-05-18T09:46:29","infoCode":"APPH3nh7x1YaASearchReport","insCode":"10001005","insName":"东北证券","insStar":"3","jlrs":["2943580000","3433140000","3952000000","",""],"rate":"增持","secuFullCode":"603288.SH","secuName":"海天味业","sratingName":"增持","sy":"0.9300","syls":["27.33","23.44","20.36","",""],"sys":["1.09","1.27","1.46","",""],"title":"关注集中度提升和品类拓展","profitYear":"2015","type":"1","newPrice":"32.18"},{"author":"胡彦超","change":"维持","companyCode":"80064560","datetime":"2016-05-03T08:19:46","infoCode":"APPH3k9IzuzgASearchReport","insCode":"80000157","insName":"中泰证券","insStar":"4","jlrs":["3013000000","3575000000","","",""],"rate":"买入","secuFullCode":"603288.SH","secuName":"海天味业","sratingName":"买入","sy":"0.9300","syls":["30","","","",""],"sys":["1.11","1.32","","",""],"title":"业绩增速略有放缓，期待今年外延拓展和新兴业务突破","profitYear":"2015","type":"1","newPrice":"32.18"},{"author":"王永锋","change":"调低","companyCode":"80064560","datetime":"2016-05-03T15:31:56","infoCode":"APPH3k9IzvvrASearchReport","insCode":"10001075","insName":"广发证券","insStar":"4","jlrs":["2902000000","3327000000","3802000000","",""],"rate":"中性","secuFullCode":"603288.SH","secuName":"海天味业","sratingName":"持有","sy":"0.9300","syls":["27","24","21","",""],"sys":["1.07","1.23","1.4","",""],"title":"业绩被透支低于预期，毛利率创新高显龙头优势","profitYear":"2015","type":"1","newPrice":"32.18"},{"author":"张宇光,文献,汤玮亮,王俏怡","change":"维持","companyCode":"80064560","datetime":"2016-04-29T10:52:22","infoCode":"APPH3SbEauJEASearchReport","insCode":"80000037","insName":"平安证券","insStar":"4","jlrs":["3010000000","3551000000","4120000000","",""],"rate":"买入","secuFullCode":"603288.SH","secuName":"海天味业","sratingName":"强烈推荐","sy":"0.9300","syls":["26","22","19","",""],"sys":["1.11","1.31","1.52","",""],"title":"短期增速下滑，长期趋势看好","profitYear":"2015","type":"1","newPrice":"32.18"},{"author":"黄付生","change":"维持","companyCode":"80064560","datetime":"2016-04-29T15:13:05","infoCode":"APPH3SbEavU1ASearchReport","insCode":"80066058","insName":"中信建投","insStar":"5","jlrs":["","","","",""],"rate":"增持","secuFullCode":"603288.SH","secuName":"海天味业","sratingName":"增持","sy":"0.9300","syls":["24.63","20.9","18.61","",""],"sys":["1.1","1.3","1.46","",""],"title":"营收、净利增速放缓 产品结构调整后期待毛利率新突破","profitYear":"2015","type":"1","newPrice":"32.18"},{"author":"黄肇蕾","change":"维持","companyCode":"80064560","datetime":"2016-04-29T19:08:58","infoCode":"APPH3SbEazX1ASearchReport","insCode":"80086668","insName":"瑞银证券","insStar":"","jlrs":["","","","",""],"rate":"持有","secuFullCode":"603288.SH","secuName":"海天味业","sratingName":"买入","sy":"0.9300","syls":["33","27","","",""],"sys":["1.1","1.31","1.54","",""],"title":"1季度收入增长低于预期，中长期趋势不改","profitYear":"2015","type":"1","newPrice":"32.18"},{"author":"朱会振","change":"维持","companyCode":"80064560","datetime":"2016-03-17T13:22:16","infoCode":"APPH313dAqifASearchReport","insCode":"10000296","insName":"西南证券","insStar":"3","jlrs":["3012510000","3620860000","4276450000","",""],"rate":"买入","secuFullCode":"603288.SH","secuName":"海天味业","sratingName":"买入","sy":"0.9300","syls":["27.69","23.03","19.5","",""],"sys":["","","","",""],"title":"2015年年报点评：业绩稳定增长，非酱油类产品表现靓丽","profitYear":"2015","type":"1","newPrice":"32.18"},{"author":"周家杏","change":"","companyCode":"80064560","datetime":"2016-03-14T13:21:05","infoCode":"APPH2zKfNCnaASearchReport","insCode":"10001043","insName":"国元证券","insStar":"4","jlrs":["","","","",""],"rate":"买入","secuFullCode":"603288.SH","secuName":"海天味业","sratingName":"买入","sy":"0.9300","syls":["","","","",""],"sys":["1.07","1.33","","",""],"title":"逆经济周期稀缺标的","profitYear":"2015","type":"1","newPrice":"32.18"},{"author":"张宇光,文献,汤玮亮,王俏怡","change":"维持","companyCode":"80064560","datetime":"2016-03-14T14:42:25","infoCode":"APPH2zKfNCygASearchReport","insCode":"80000037","insName":"平安证券","insStar":"4","jlrs":["3010000000","3551000000","4120000000","",""],"rate":"买入","secuFullCode":"603288.SH","secuName":"海天味业","sratingName":"强烈推荐","sy":"0.9300","syls":["24.9","21.1","18.2","",""],"sys":["1.11","1.31","1.52","",""],"title":"竞争力持续提升，盈利性趋势向好","profitYear":"2015","type":"1","newPrice":"32.18"},{"author":"徐昊,焦凯","change":"维持","companyCode":"80064560","datetime":"2016-03-14T15:02:19","infoCode":"APPH2zKfNCzzASearchReport","insCode":"80114781","insName":"东兴证券","insStar":"1","jlrs":["2988000000","3428000000","3903000000","",""],"rate":"买入","secuFullCode":"603288.SH","secuName":"海天味业","sratingName":"强烈推荐","sy":"0.9300","syls":["25","21","19","",""],"sys":["1.1","1.27","1.44","",""],"title":"2015年财报点评：产品升级+渠道下沉，看好公司发展","profitYear":"2015","type":"1","newPrice":"32.18"},{"author":"苏铖","change":"维持","companyCode":"80064560","datetime":"2016-03-13T10:29:18","infoCode":"APPH2ychajwsASearchReport","insCode":"80084302","insName":"安信证券","insStar":"4","jlrs":["3000900000","3559500000","4154300000","",""],"rate":"买入","secuFullCode":"603288.SH","secuName":"海天味业","sratingName":"买入","sy":"0.9300","syls":["26","22","18.5","",""],"sys":["1.11","1.32","1.54","",""],"title":"新品类成长亮眼，整体发展稳健","profitYear":"2015","type":"1","newPrice":"32.18"},{"author":"研究部","change":"维持","companyCode":"80064560","datetime":"2016-03-11T00:00:00","infoCode":"APPH31kaxQC2ASearchReport","insCode":"80140572","insName":"元大证券(香港)","insStar":"1","jlrs":["3200000000","3859000000","","",""],"rate":"增持","secuFullCode":"603288.SH","secuName":"海天味业","sratingName":"买进","sy":"0.9300","syls":["24","19.9","","",""],"sys":["1.18","1.43","","",""],"title":"业务发展前景日益广阔","profitYear":"2015","type":"1","newPrice":"32.18"},{"author":"李晓璐","change":"维持","companyCode":"80064560","datetime":"2016-03-11T08:32:08","infoCode":"APPH2ychagh1ASearchReport","insCode":"80000119","insName":"群益证券","insStar":"1","jlrs":["3038000000","3536000000","","",""],"rate":"增持","secuFullCode":"603288.SH","secuName":"海天味业","sratingName":"买入","sy":"0.9300","syls":["24.22","21","","",""],"sys":["1.12","1.31","","",""],"title":"2015年纯利同比增20%，产品推陈出新","profitYear":"2015","type":"1","newPrice":"32.18"},{"author":"余春生","change":"维持","companyCode":"80064560","datetime":"2016-03-11T08:35:42","infoCode":"APPH2ychagh2ASearchReport","insCode":"10001055","insName":"国海证券","insStar":"3","jlrs":["2932000000","3464000000","4078000000","",""],"rate":"增持","secuFullCode":"603288.SH","secuName":"海天味业","sratingName":"增持","sy":"0.9300","syls":["25.1","21.24","18.04","",""],"sys":["1.08","1.28","1.51","",""],"title":"2015年年报点评：2015年营收突破百亿，规模效应有望更为显现","profitYear":"2015","type":"1","newPrice":"32.18"},{"author":"张威威","change":"维持","companyCode":"80064560","datetime":"2016-03-11T17:56:32","infoCode":"APPH2ychaij7ASearchReport","insCode":"80000082","insName":"长城证券","insStar":"4","jlrs":["2940120000","3467430000","4011300000","",""],"rate":"增持","secuFullCode":"603288.SH","secuName":"海天味业","sratingName":"推荐","sy":"0.9300","syls":["26.16","22.18","19.17","",""],"sys":["1.09","1.28","1.48","",""],"title":"年报点评：主动进行变革，2015稳健收官","profitYear":"2015","type":"1","newPrice":"32.18"},{"author":"胡彦超","change":"维持","companyCode":"80064560","datetime":"2016-03-10T09:04:50","infoCode":"APPH2yNiK8eKASearchReport","insCode":"80000157","insName":"中泰证券","insStar":"4","jlrs":["2510000000","3013000000","3575000000","",""],"rate":"买入","secuFullCode":"603288.SH","secuName":"海天味业","sratingName":"买入","sy":"0.9300","syls":["30","","","",""],"sys":["0.927","1.113","1.321","",""],"title":"超预期的收入！不同凡响的2016？","profitYear":"2015","type":"1","newPrice":"32.18"},{"author":"王永锋","change":"维持","companyCode":"80064560","datetime":"2016-03-10T10:09:36","infoCode":"APPH2yNiK8qEASearchReport","insCode":"10001075","insName":"广发证券","insStar":"4","jlrs":["2994000000","3473000000","4017000000","",""],"rate":"买入","secuFullCode":"603288.SH","secuName":"海天味业","sratingName":"买入","sy":"0.9300","syls":["24.6","21.2","18.3","",""],"sys":["1.11","1.28","1.48","",""],"title":"业绩保持确定性的稳健增长，未来关注品类扩张","profitYear":"2015","type":"1","newPrice":"32.18"}],"pages":"5","update":"2016-08-17","count":"112"}'

# %%
jsontext = json.loads(text)

# %%
jsontext['count']
# Out:
# '112'

# %%
jsontext['pages']
# Out:
# '5'

# %%
jsontext['update']
# Out:
# '2016-08-17'

# %%
jsontext['data']
# Out:
# [{'author': '朱会振',
#   'change': '维持',
#   'companyCode': '80064560',
#   'datetime': '2016-08-17T08:06:15',
#   'infoCode': 'APPH51aNXPpRASearchReport',
#   'insCode': '10000296',
#   'insName': '西南证券',
#   'insStar': '3',
#   'jlrs': ['3003920000', '3593240000', '4225910000', '', ''],
#   'newPrice': '32.18',
#   'profitYear': '2015',
#   'rate': '买入',
#   'secuFullCode': '603288.SH',
#   'secuName': '海天味业',
#   'sratingName': '买入',
#   'sy': '0.9300',
#   'syls': ['29', '24', '21', '', ''],
#   'sys': ['1.11', '1.33', '1.56', '', ''],
#   'title': '业绩稳健增长，盈利能力创历史新高',
#   'type': '1'},
#  {'author': '陈鹏,李强,余驰',
#   'change': '维持',
#   'companyCode': '80064560',
#   'datetime': '2016-08-17T11:31:30',
#   'infoCode': 'APPH51aNXRU7ASearchReport',
#   'insCode': '10001005',
#   'insName': '东北证券',
#   'insStar': '3',
#   'jlrs': ['2875330000', '3285390000', '3785470000', '', ''],
#   'newPrice': '32.18',
#   'profitYear': '2015',
#   'rate': '增持',
#   'secuFullCode': '603288.SH',
# ...

# %%
import pandas

# %%
pd = pandas.DataFrame(jsontext['data'])

# %%
pd
# Out:
#             author change companyCode             datetime  \
# 0              朱会振     维持    80064560  2016-08-17T08:06:15
# 1         陈鹏,李强,余驰     维持    80064560  2016-08-17T11:31:30
# 2              余春生     维持    80064560  2016-08-17T13:20:47
# 3              胡彦超     维持    80064560  2016-08-16T09:15:36
# 4       张宇光,文献,王俏怡     维持    80064560  2016-08-16T09:37:30
# 5               刘颜     维持    80064560  2016-08-16T14:23:40
# 6              黄付生     维持    80064560  2016-08-16T18:45:21
# 7       张宇光,文献,王俏怡     维持    80064560  2016-06-30T08:36:32
# 8         陈鹏,李强,余驰     维持    80064560  2016-05-18T09:46:29
# 9              胡彦超     维持    80064560  2016-05-03T08:19:46
# 10             王永锋     调低    80064560  2016-05-03T15:31:56
# 11  张宇光,文献,汤玮亮,王俏怡     维持    80064560  2016-04-29T10:52:22
# 12             黄付生     维持    80064560  2016-04-29T15:13:05
# 13             黄肇蕾     维持    80064560  2016-04-29T19:08:58
# 14             朱会振     维持    80064560  2016-03-17T13:22:16
# ...
